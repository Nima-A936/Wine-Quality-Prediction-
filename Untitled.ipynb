# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import os
from matplotlib import pyplot as plt
import cv2

# %%
df = pd.read_csv(
    os.path.join("winequality-red.csv")
)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
x = df.drop("quality" , axis=1)
y = df['quality']
labels = df['quality'].unique()
scaled = df["quality"].value_counts()
print(f'labels : {labels} ')
print(scaled)
# Out:
# labels : [5 6 7 4 8 3]
# quality
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
ex = {3:"Bad" ,4:"Bad" ,5:"Mid" ,6:"Fine" ,7:"Fine" ,8:"Fine"}
df["Expression"] = df["quality"].map(ex)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
plt.figure(figsize=(5,5))
plt.style.use("fivethirtyeight")
fig , ax = plt.subplots(nrows=1 , ncols=1)
colors = []
for label in labels:
    if label > 5:
        colors.append("green")
    elif label == 5:
        colors.append("gold")
    elif label < 5:
        colors.append("red")      
plot = ax.bar(
    labels ,scaled , color=colors , edgecolor='black',
    linewidth=0.2 , 
)
plt.title("Red-Wine-Quality" , fontname="Arial" , fontstyle="italic")
plt.xlabel("Qualities" , fontname="Arial" , fontstyle="italic" , size = 12)
plt.xticks(labels , fontname='Arial' , fontstyle='italic' , size=12)
plt.bar_label(plot , fontname='Arial' , fontstyle='italic' , size=12)
plt.show()

# %%
fig = plt.figure(figsize=(8,8))
plt.style.use("dark_background")
axs = fig.subplots(nrows=3 , ncols=3)
axs = axs.flatten()
colors=["red","red","red","blue","blue","blue","gold","gold","gold"]
variables = ["fixed acidity","volatile acidity","citric acid","pH","residual sugar","chlorides","free sulfur dioxide","total sulfur dioxide","density"]
for ax,var,col in zip(axs,variables,colors):
    ax.scatter(x=df["alcohol"] , y=df[var] , color=col , s=15)
    ax.set_xlabel("Alcohol")
    ax.set_ylabel(var.title())
plt.show()

# %%
x_train, x_test ,y_train ,y_test = train_test_split(x,y , test_size=0.3 )

# %%
model = DecisionTreeRegressor()
model1 = LinearRegression()

# %%
history = model.fit(x_train,y_train)
history1 = model1.fit(x_train,y_train)

# %%
loc = x.iloc[[19]]
loc2 = df[df['quality'] == 6]
df2 = pd.DataFrame({
    "fixed acidity" : [7.4],
    "volatile acidity" : [0.700],
    "citric acid" : [0.00],
    "residual sugar" : [1.9],
    "chlorides" : [0.076],
    "free sulfur dioxide" : [11.0],
    "total sulfur dioxide" : [34.0],
    "density" : [0.99780],
    "pH" : [3.16],
    "sulphates" : [0.58],
    "alcohol" : [9.8]
})
score = model.score(x_train,y_train)
predict = model.predict(loc)
print(score)
print(predict)
img_path = "/kaggle/input/how-many-ounces-in-a-glass-of-wine.jpg"
img = cv2.imread(img_path)
#img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
if predict > 5:
    plt.imshow(img)
    plt.grid(False)
    plt.title("Fine Wine")
    print("Red-Wine's Quality : Fine")
if predict == 5:
    print("Red-Wine's Quality : Mid")
if predict < 5:
    print("Red-Wine's Quality : Bad")
# Out:
# 1.0
# [6.]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 24
#      22 #img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#      23 if predict > 5:
# ---> 24     plt.imshow(img)
#      25     plt.grid(False)
#      26     plt.title("Fine Wine")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3358, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3337 @_copy_docstring_and_deprecators(Axes.imshow)
#    3338 def imshow(
#    3339     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3356     **kwargs,
#    3357 ) -> AxesImage:
# -> 3358     __ret = gca().imshow(
#    3359         X,
#    3360         cmap=cmap,
#    3361         norm=norm,
#    3362         aspect=aspect,
# ...

# %%
df.head(20)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# ...

# %%
loc
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4               0.7          0.0             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4

# %%
loc2
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3              11.2             0.280         0.56             1.9      0.075
# 19              7.9             0.320         0.51             1.8      0.341
# 20              8.9             0.220         0.48             1.8      0.077
# 24              6.9             0.400         0.14             2.4      0.085
# 29              7.8             0.645         0.00             2.0      0.082
# ...             ...               ...          ...             ...        ...
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...
